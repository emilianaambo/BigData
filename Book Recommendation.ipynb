# %% [markdown]
# # Reading the data files

# %%
#importing the libraries
import pandas as pd
import numpy as np

# %%
#Reading the csv files
dfbooks=pd.read_csv('../data/raw/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
dfbooks.columns = ['ISBN', 'Title', 'Author', 'YearOfPublication', 'Publisher', 'ImageUrlS', 'ImageUrlM', 'ImageUrlL']
dfusers=pd.read_csv('../data/raw/BX-Users.csv', sep=';', error_bad_lines=False, encoding="latin-1")
dfusers.columns = ['UserID', 'Location', 'Age']
dfratings= pd.read_csv('../data/raw/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
dfratings.columns = ['UserID', 'ISBN', 'Ratings']
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# /Users/emilianaambo/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Inspecting the different datasets we have by using sample(5) by sampling randomly 5 coloumns in the dataset to view the data in each dataset and also shape to view shape of each dataset.

# %%
#view the 5 random records from a books dataframe to see how the data is 
dfbooks.sample(5)
# Out:
#               ISBN                                              Title  \
# 202792  0064441407       Porcupine's Pajama Party (I Can Read Book 2)
# 71009   0553452770                                Wild Mountain Thyme
# 128515  0140242996  Lady Chatterley's Lover: According to Spike Mi...
# 53847   3770161378                      Namibia. Aktuelle Reisetipps.
# 88588   0971386757  Your Love Life and Reincarnation: Why The Past...
#
#                      Author YearOfPublication                    Publisher  \
# 202792  Terry Webb Harshman              1990                 HarperTrophy
# 71009     Rosamunde Pilcher              1991           Random House Audio
# 128515       Spike Milligan              1999  Penguin Books, Limited (UK)
# 53847            Livia Pack              2002           Dumont Reiseverlag
# 88588       Stephen Petullo              2002                     Metapub.
#
#                                                 ImageUrlS  \
# 202792  http://images.amazon.com/images/P/0064441407.0...
# 71009   http://images.amazon.com/images/P/0553452770.0...
# 128515  http://images.amazon.com/images/P/0140242996.0...
# 53847   http://images.amazon.com/images/P/3770161378.0...
# 88588   http://images.amazon.com/images/P/0971386757.0...
#
#                                                 ImageUrlM  \
# 202792  http://images.amazon.com/images/P/0064441407.0...
# 71009   http://images.amazon.com/images/P/0553452770.0...
# 128515  http://images.amazon.com/images/P/0140242996.0...
# 53847   http://images.amazon.com/images/P/3770161378.0...
# 88588   http://images.amazon.com/images/P/0971386757.0...
#
#                                                 ImageUrlL
# 202792  http://images.amazon.com/images/P/0064441407.0...
# 71009   http://images.amazon.com/images/P/0553452770.0...
# 128515  http://images.amazon.com/images/P/0140242996.0...
# 53847   http://images.amazon.com/images/P/3770161378.0...
# 88588   http://images.amazon.com/images/P/0971386757.0...

# %%
#view the 5 random records from a ratings dataframe to see how the data is 
dfratings.sample(5)
# Out:
#          UserID        ISBN  Ratings
# 130829    30276  0743467132        0
# 240761    55493  0146000358        0
# 84313     17859  0385491832        0
# 1093999  262399  0553580191        0
# 146969    32793  2010178750        7

# %%
#view the 5 random records from a users dataframe to see how the data is 
dfusers.sample(5)
# Out:
#         UserID                    Location   Age
# 66086    66087       norman, oklahoma, usa   NaN
# 250135  250136    johnsburg, illinois, usa  61.0
# 7624      7625     new york, new york, usa   NaN
# 60648    60649    st. louis, missouri, usa  24.0
# 57363    57364  mt. juliet, tennessee, usa  24.0

# %%
#viewing the shapes of the different datasets
print(dfbooks.shape)
print(dfusers.shape)
print(dfratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %% [markdown]
# ## Books Dataset

# %%
#viewing columns in Books dataframe
dfbooks.columns
# Out:
# Index(['ISBN', 'Title', 'Author', 'YearOfPublication', 'Publisher',
#        'ImageUrlS', 'ImageUrlM', 'ImageUrlL'],
#       dtype='object')

# %%
#Viewing a description of  all columns of books dataframe 
dfbooks.describe(include='all')
# Out:
#               ISBN           Title           Author  YearOfPublication  \
# count       271360          271360           271359             271360
# unique      271360          242135           102023                202
# top     1569473447  Selected Poems  Agatha Christie               2002
# freq             1              27              632              13903
#
#         Publisher                                          ImageUrlS  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/038072118X.0...
# freq         7535                                                  2
#
#                                                 ImageUrlM  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/349222539X.0...
# freq                                                    2
#
#                                                 ImageUrlL
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/044022859X.0...
# freq                                                    2

# %%
#Checking for any duplicates
dfbooks.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 271330    False
# 271331    False
# 271332    False
# 271333    False
# 271334    False
# 271335    False
# 271336    False
# 271337    False
# 271338    False
# 271339    False
# 271340    False
# 271341    False
# 271342    False
# 271343    False
# 271344    False
# 271345    False
# 271346    False
# 271347    False
# 271348    False
# 271349    False
# 271350    False
# 271351    False
# 271352    False
# 271353    False
# 271354    False
# 271355    False
# 271356    False
# 271357    False
# 271358    False
# 271359    False
# Length: 271360, dtype: bool

# %%
#Checking for any missing values
dfbooks.isnull().sum()
# Out:
# ISBN                 0
# Title                0
# Author               1
# YearOfPublication    0
# Publisher            2
# ImageUrlS            0
# ImageUrlM            0
# ImageUrlL            3
# dtype: int64

# %% [markdown]
# We can observe that we have missing values in 3 columns: Author, Publisher,and ImageUrlL

# %%
#Total number of missing values
dfbooks.isnull().sum().sum()
# Out:
# 6

# %% [markdown]
# Here we can see that there are missing values in some columns, this could be because of NAN values present or no values at all

# %%
#counting the number of records in each column
dfbooks.count()
# Out:
# ISBN                 271360
# Title                271360
# Author               271359
# YearOfPublication    271360
# Publisher            271358
# ImageUrlS            271360
# ImageUrlM            271360
# ImageUrlL            271357
# dtype: int64

# %% [markdown]
# We can see that the total count of the missing values in the books dataframe

# %%
#viewing details of dataframe using info()
dfbooks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
# ISBN                 271360 non-null object
# Title                271360 non-null object
# Author               271359 non-null object
# YearOfPublication    271360 non-null object
# Publisher            271358 non-null object
# ImageUrlS            271360 non-null object
# ImageUrlM            271360 non-null object
# ImageUrlL            271357 non-null object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %% [markdown]
# We can see that the column:YearOfPublication is of object dataype of which it was supposed to be of int datatype, let's further inspect the data in the columns

# %% [markdown]
# Let's further view the data present in the YearOfPublication column

# %%
#checking unique values of YearOfPublication 
dfbooks.YearOfPublication.unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
#        '1963', '1956', '1970', '1985', '1978', '1973', '1980', '1979',
#        '1975', '1969', '1961', '1965', '1939', '1958', '1950', '1953',
#        '1966', '1971', '1959', '1972', '1955', '1957', '1945', '1960',
#        '1967', '1932', '1924', '1964', '2012', '1911', '1927', '1948',
#        '1962', '2006', '1952', '1940', '1951', '1931', '1954', '2005',
#        '1930', '1941', '1944', 'DK Publishing Inc', '1943', '1938',
#        '1900', '1942', '1923', '1920', '1933', 'Gallimard', '1909',
#        '1946', '2008', '1378', '2030', '1936', '1947', '2011', '2020',
#        '1919', '1949', '1922', '1897', '2024', '1376', '1926', '2037'],
#       dtype=object)

# %% [markdown]
# We can observe that some data is not entirely year, but some entries that are words instead of year values.

# %%
#Let's investigate further in the YearOfPublicationthe column, the row(s) that have "Gallimard" 
dfbooks.loc[dfbooks.YearOfPublication == 'Gallimard',:]
# Out:
#               ISBN                                              Title Author  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...   2003
#
#        YearOfPublication                                          Publisher  \
# 220731         Gallimard  http://images.amazon.com/images/P/2070426769.0...
#
#                                                 ImageUrlS  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                                 ImageUrlM ImageUrlL
# 220731  http://images.amazon.com/images/P/2070426769.0...       NaN

# %%
#Let's investigate further in the YearOfPublicationthe column, the row(s) that have "DK Publishing Inc" 
dfbooks.loc[dfbooks.YearOfPublication == 'DK Publishing Inc',:]
# Out:
#               ISBN                                              Title Author  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...   2000
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...   2000
#
#         YearOfPublication                                          Publisher  \
# 209538  DK Publishing Inc  http://images.amazon.com/images/P/078946697X.0...
# 221678  DK Publishing Inc  http://images.amazon.com/images/P/0789466953.0...
#
#                                                 ImageUrlS  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                                 ImageUrlM ImageUrlL
# 209538  http://images.amazon.com/images/P/078946697X.0...       NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...       NaN

# %% [markdown]
# From the results, you can observe that it seems like for some reason there was a mixup with loaded data and Author details are in the Title column,while the Author column contains the values for the year.

# %%
#fixing the incorrect data in Title, Author, YearOfPublication and Publisher columns for Gallimard
dfbooks.loc[dfbooks.ISBN == '2070426769','YearOfPublication'] = 2003
#searched the correct spelling of the Author changed from 'Jean-Marie Gustave Le ClÃ?Â©zio' to 'Jean-Marie Gustave Le Clézio' 
dfbooks.loc[dfbooks.ISBN == '2070426769','Author'] = "Jean-Marie Gustave Le Clézio "
dfbooks.loc[dfbooks.ISBN == '2070426769','Publisher'] = "Gallimard"
dfbooks.loc[dfbooks.ISBN == '2070426769','Title'] = "Peuple du ciel, suivi de 'Les Bergers"
dfbooks.loc[dfbooks.ISBN== '2070426769',:]
# Out:
#               ISBN                                  Title  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers
#
#                                Author YearOfPublication  Publisher  \
# 220731  Jean-Marie Gustave Le Clézio               2003  Gallimard
#
#                                                 ImageUrlS  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                                 ImageUrlM ImageUrlL
# 220731  http://images.amazon.com/images/P/2070426769.0...       NaN

# %%
#fixing the incorrect data in Title, Author, YearOfPublication and Publisher columns for DK Publishing Inc with ISBN =0789466953
dfbooks.loc[dfbooks.ISBN == '0789466953','YearOfPublication'] = 2000
dfbooks.loc[dfbooks.ISBN == '0789466953','Author'] = "James Buckley"
dfbooks.loc[dfbooks.ISBN == '0789466953','Publisher'] = "DK Publishing Inc"
dfbooks.loc[dfbooks.ISBN == '0789466953','Title'] = "DK Readers: Creating the X-Men, How Comic Books Come to Life (Level 4: Proficient Readers)"
dfbooks.loc[dfbooks.ISBN == '0789466953',:]
# Out:
#               ISBN                                              Title  \
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#                Author YearOfPublication          Publisher  \
# 221678  James Buckley              2000  DK Publishing Inc
#
#                                                 ImageUrlS  \
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                                 ImageUrlM ImageUrlL
# 221678  http://images.amazon.com/images/P/0789466953.0...       NaN

# %%
#fixing the incorrect data in Title, Author, YearOfPublication and Publisher columns for DK Publishing Inc with ISBN = 078946697X
dfbooks.loc[dfbooks.ISBN == '078946697X','YearOfPublication'] = 2000
dfbooks.loc[dfbooks.ISBN == '078946697X','Author'] = "Michael Teitelbaum"
dfbooks.loc[dfbooks.ISBN == '078946697X','Publisher'] = "DK Publishing Inc"
dfbooks.loc[dfbooks.ISBN == '078946697X','Title'] = "DK Readers: Creating the X-Men, How It All Began (Level 4: Proficient Readers)"
dfbooks.loc[dfbooks.ISBN == '078946697X',:]
# Out:
#               ISBN                                              Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
#
#                     Author YearOfPublication          Publisher  \
# 209538  Michael Teitelbaum              2000  DK Publishing Inc
#
#                                                 ImageUrlS  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
#
#                                                 ImageUrlM ImageUrlL
# 209538  http://images.amazon.com/images/P/078946697X.0...       NaN

# %%
#viewing datat in the YearOfPublication column
dfbooks.YearOfPublication
# Out:
# 0         2002
# 1         2001
# 2         1991
# 3         1999
# 4         1999
# 5         1991
# 6         2000
# 7         1993
# 8         1996
# 9         2002
# 10        1988
# 11        2000
# 12        2004
# 13        1999
# 14        1998
# 15        1998
# 16        1999
# 17        1994
# 18        1999
# 19        1994
# 20        1999
# 21        2001
# 22        2003
# 23        2000
# 24        1999
# 25        1998
# 26        2004
# 27        1997
# 28        2000
# 29        1996
#           ...
# 271330    1990
# 271331    1997
# 271332    1993
# 271333    1994
# 271334    2001
# 271335    1989
# 271336    1995
# 271337    2002
# 271338    1997
# 271339    2003
# 271340    2003
# 271341    1998
# 271342    2001
# 271343    1998
# 271344    1999
# 271345    1999
# 271346    1978
# 271347    2000
# 271348    2003
# 271349    2004
# 271350    2002
# 271351    2001
# 271352    2004
# 271353    1975
# 271354    1993
# 271355    1988
# 271356    1991
# 271357    2004
# 271358    1996
# 271359    2000
# Name: YearOfPublication, Length: 271360, dtype: object

# %% [markdown]
# Let's inspect the data in YearOfPublication once again. We can see value of 0.
# We can see that there are incorrect values for since the data was collected in 2004, meaning we are not supposed to be seeing any YearOfPublication data more than 2004 and even worse more than our current year 2019 like 2024. We can already conclude that most of the values in YearOfPublication are incorrect. We will try to correct the dataset by setting invalid values such as 0 and more than 2004 to NaN.

# %%
#Changing YearOfPublication column to numeric
dfbooks.YearOfPublication=pd.to_numeric(dfbooks.YearOfPublication, errors='coerce')

# %%
#Setting the invalid YearOfPublication entries to NaN
dfbooks.loc[(dfbooks.YearOfPublication == 0), 'YearOfPublication'] = np.nan
dfbooks.loc[(dfbooks.YearOfPublication > 2004), 'YearOfPublication'] = np.nan
dfbooks.YearOfPublication.unique()
# Out:
# array([2002., 2001., 1991., 1999., 2000., 1993., 1996., 1988., 2004.,
#        1998., 1994., 2003., 1997., 1983., 1979., 1995., 1982., 1985.,
#        1992., 1986., 1978., 1980., 1952., 1987., 1990., 1981., 1989.,
#        1984.,   nan, 1968., 1961., 1958., 1974., 1976., 1971., 1977.,
#        1975., 1965., 1941., 1970., 1962., 1973., 1972., 1960., 1966.,
#        1920., 1956., 1959., 1953., 1951., 1942., 1963., 1964., 1969.,
#        1954., 1950., 1967., 1957., 1940., 1937., 1955., 1946., 1936.,
#        1930., 1925., 1948., 1943., 1947., 1945., 1923., 1939., 1926.,
#        1938., 1911., 1904., 1949., 1932., 1928., 1929., 1927., 1931.,
#        1914., 1934., 1910., 1933., 1902., 1924., 1921., 1900., 1944.,
#        1917., 1901., 1908., 1906., 1935., 1806., 1909., 1378., 1919.,
#        1922., 1897., 1376.])

# %%
#To assign values to NaNs, lets replace using the mean value for the YearOfPublication column
dfbooks.YearOfPublication.fillna(round(dfbooks.YearOfPublication.mean()), inplace=True)
dfbooks.YearOfPublication.unique()
# Out:
# array([2002., 2001., 1991., 1999., 2000., 1993., 1996., 1988., 2004.,
#        1998., 1994., 2003., 1997., 1983., 1979., 1995., 1982., 1985.,
#        1992., 1986., 1978., 1980., 1952., 1987., 1990., 1981., 1989.,
#        1984., 1968., 1961., 1958., 1974., 1976., 1971., 1977., 1975.,
#        1965., 1941., 1970., 1962., 1973., 1972., 1960., 1966., 1920.,
#        1956., 1959., 1953., 1951., 1942., 1963., 1964., 1969., 1954.,
#        1950., 1967., 1957., 1940., 1937., 1955., 1946., 1936., 1930.,
#        1925., 1948., 1943., 1947., 1945., 1923., 1939., 1926., 1938.,
#        1911., 1904., 1949., 1932., 1928., 1929., 1927., 1931., 1914.,
#        1934., 1910., 1933., 1902., 1924., 1921., 1900., 1944., 1917.,
#        1901., 1908., 1906., 1935., 1806., 1909., 1378., 1919., 1922.,
#        1897., 1376.])

# %%
#Confirming if there are no NaNs present
dfbooks.YearOfPublication.isnull().sum()
# Out:
# 0

# %%
#Converting datatype for YearOfPublication column to int32
dfbooks.YearOfPublication = dfbooks.YearOfPublication.astype(np.int32)
dfbooks.sample(5)
# Out:
#               ISBN                                            Title  \
# 64778   1577489195     The Hiding Place (Deluxe Christian Classics)
# 173414  1582340277              Five Pubs, Two Bars and a Nightclub
# 78344   0394719484                    A Book of Middle Eastern Food
# 53237   3421054118  Grossmutter und Lebensweisheiten und ich: Roman
# 201410  0736602399                                       Earthlight
#
#                   Author  YearOfPublication                   Publisher  \
# 64778    Corrie Ten Boom               2000          Barbour Publishing
# 173414     John Williams               1999  Bloomsbury Publishing (NY)
# 78344      Claudia Roden               1974           Vintage Books USA
# 53237       Susanne Alge               2000    Deutsche Verlags-Anstalt
# 201410  Arthur C. Clarke               1979         Books on Tape, Inc.
#
#                                                 ImageUrlS  \
# 64778   http://images.amazon.com/images/P/1577489195.0...
# 173414  http://images.amazon.com/images/P/1582340277.0...
# 78344   http://images.amazon.com/images/P/0394719484.0...
# 53237   http://images.amazon.com/images/P/3421054118.0...
# 201410  http://images.amazon.com/images/P/0736602399.0...
#
#                                                 ImageUrlM  \
# 64778   http://images.amazon.com/images/P/1577489195.0...
# 173414  http://images.amazon.com/images/P/1582340277.0...
# 78344   http://images.amazon.com/images/P/0394719484.0...
# 53237   http://images.amazon.com/images/P/3421054118.0...
# 201410  http://images.amazon.com/images/P/0736602399.0...
#
#                                                 ImageUrlL
# 64778   http://images.amazon.com/images/P/1577489195.0...
# 173414  http://images.amazon.com/images/P/1582340277.0...
# 78344   http://images.amazon.com/images/P/0394719484.0...
# 53237   http://images.amazon.com/images/P/3421054118.0...
# 201410  http://images.amazon.com/images/P/0736602399.0...

# %%
#Let's drop the columns "ImageUrlS" and "ImageUrlM" and  "ImageUrlL"
dfbooks.drop(["ImageUrlS","ImageUrlM","ImageUrlL"], axis=1, inplace=True)
dfbooks.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  YearOfPublication                   Publisher
# 0    Mark P. O. Morford               2002     Oxford University Press
# 1  Richard Bruce Wright               2001       HarperFlamingo Canada
# 2          Carlo D'Este               1991             HarperPerennial
# 3      Gina Bari Kolata               1999        Farrar Straus Giroux
# 4       E. J. W. Barber               1999  W. W. Norton &amp; Company

# %%
#Checking that there are no duplicated book entries
uniq_books = dfbooks.ISBN.nunique()
all_books = dfbooks.ISBN.count()
print(f'No. of unique books: {uniq_books} | All book entries: {all_books}')
# Out:
# No. of unique books: 271360 | All book entries: 271360

# %% [markdown]
# ## Users Dataset

# %%
#viewing columns in Users dataframe
dfusers.columns
# Out:
# Index(['UserID', 'Location', 'Age'], dtype='object')

# %%
#checks details for users dataframe using info()
dfusers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
# UserID      278858 non-null int64
# Location    278858 non-null object
# Age         168096 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %% [markdown]
# We can see that the Age column is of float datatype instead of int

# %%
#Viewing a description of all columns of Users dataframe  
dfusers.describe(include='all')
# Out:
#               UserID                         Location            Age
# count   278858.00000                           278858  168096.000000
# unique           NaN                            57339            NaN
# top              NaN  london, england, united kingdom            NaN
# freq             NaN                             2506            NaN
# mean    139429.50000                              NaN      34.751434
# std      80499.51502                              NaN      14.428097
# min          1.00000                              NaN       0.000000
# 25%      69715.25000                              NaN      24.000000
# 50%     139429.50000                              NaN      32.000000
# 75%     209143.75000                              NaN      44.000000
# max     278858.00000                              NaN     244.000000

# %%
#viewing count of records in each column
dfusers.count()
# Out:
# UserID      278858
# Location    278858
# Age         168096
# dtype: int64

# %%
#Checking for any missing values
dfusers.isnull().sum()
# Out:
# UserID           0
# Location         0
# Age         110762
# dtype: int64

# %%
#Checking for any duplicates
dfusers.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 278828    False
# 278829    False
# 278830    False
# 278831    False
# 278832    False
# 278833    False
# 278834    False
# 278835    False
# 278836    False
# 278837    False
# 278838    False
# 278839    False
# 278840    False
# 278841    False
# 278842    False
# 278843    False
# 278844    False
# 278845    False
# 278846    False
# 278847    False
# 278848    False
# 278849    False
# 278850    False
# 278851    False
# 278852    False
# 278853    False
# 278854    False
# 278855    False
# 278856    False
# 278857    False
# Length: 278858, dtype: bool

# %%
#checking unique values in the Age column
dfusers.Age.unique()
# Out:
# array([ nan,  18.,  17.,  61.,  26.,  14.,  25.,  19.,  46.,  55.,  32.,
#         24.,  20.,  34.,  23.,  51.,  31.,  21.,  44.,  30.,  57.,  43.,
#         37.,  41.,  54.,  42.,  50.,  39.,  53.,  47.,  36.,  28.,  35.,
#         13.,  58.,  49.,  38.,  45.,  62.,  63.,  27.,  33.,  29.,  66.,
#         40.,  15.,  60.,   0.,  79.,  22.,  16.,  65.,  59.,  48.,  72.,
#         56.,  67.,   1.,  80.,  52.,  69.,  71.,  73.,  78.,   9.,  64.,
#        103., 104.,  12.,  74.,  75., 231.,   3.,  76.,  83.,  68., 119.,
#         11.,  77.,   2.,  70.,  93.,   8.,   7.,   4.,  81., 114., 230.,
#        239.,  10.,   5., 148., 151.,   6., 101., 201.,  96.,  84.,  82.,
#         90., 123., 244., 133.,  91., 128.,  94.,  85., 141., 110.,  97.,
#        219.,  86., 124.,  92., 175., 172., 209., 212., 237.,  87., 162.,
#        100., 156., 136.,  95.,  89., 106.,  99., 108., 210.,  88., 199.,
#        147., 168., 132., 159., 186., 152., 102., 116., 200., 115., 226.,
#        137., 207., 229., 138., 109., 105., 228., 183., 204.,  98., 223.,
#        113., 208., 107., 157., 111., 146., 118., 220., 143., 140., 189.,
#        127.])

# %% [markdown]
# If we inspect closely the results,there is a discovery of data entries that are invalid like for example 0, ages less than 10 and nan including bigger numbers more than 100 like 220 etc and we all know that all those are ridiculous numbers for age.

# %% [markdown]
# Next, I will handle the invalid entries as follows:
# I will set the age values that are less than 10 and values that are more than 100 to NaN.

# %%
#Setting the invalid age entries to NaN

dfusers.loc[(dfusers.Age < 10), 'Age'] = np.nan
dfusers.loc[(dfusers.Age > 100), 'Age'] = np.nan
dfusers.head()
# Out:
#    UserID                            Location   Age
# 0       1                  nyc, new york, usa   NaN
# 1       2           stockton, california, usa  18.0
# 2       3     moscow, yukon territory, russia   NaN
# 3       4           porto, v.n.gaia, portugal  17.0
# 4       5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# To change the age column to int datatype, we will have to convert to convert NaNs to number values so in this case we use the mean of age column to replace them with.

# %%
#We replace the NaN with mean Age values
dfusers.Age = dfusers.Age.fillna(dfusers.Age.mean())
dfusers.head()
# Out:
#    UserID                            Location        Age
# 0       1                  nyc, new york, usa  34.777122
# 1       2           stockton, california, usa  18.000000
# 2       3     moscow, yukon territory, russia  34.777122
# 3       4           porto, v.n.gaia, portugal  17.000000
# 4       5  farnborough, hants, united kingdom  34.777122

# %% [markdown]
# We can see the mean value is 34 which I believe is fairly a good age.

# %%
#Confirming if there are no NaNs present
dfusers.Age.isnull().sum()
# Out:
# 0

# %% [markdown]
# Finally we convert our Age column to Int.

# %%
#converting data type from float to int
dfusers.Age = dfusers.Age.astype(np.int32)
dfusers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
# UserID      278858 non-null int64
# Location    278858 non-null object
# Age         278858 non-null int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 5.3+ MB

# %%
#Let's drop the column Location from users
dfusers.drop(["Location"], axis=1, inplace=True)
dfusers.head()
# Out:
#    UserID  Age
# 0       1   34
# 1       2   18
# 2       3   34
# 3       4   17
# 4       5   34

# %%
dfusers
# Out:
#         UserID  Age
# 0            1   34
# 1            2   18
# 2            3   34
# 3            4   17
# 4            5   34
# 5            6   61
# 6            7   34
# 7            8   34
# 8            9   34
# 9           10   26
# 10          11   14
# 11          12   34
# 12          13   26
# 13          14   34
# 14          15   34
# 15          16   34
# 16          17   34
# 17          18   25
# 18          19   14
# 19          20   19
# 20          21   46
# 21          22   34
# 22          23   34
# 23          24   19
# 24          25   55
# 25          26   34
# 26          27   32
# 27          28   24
# 28          29   19
# 29          30   24
# ...        ...  ...
# 278828  278829   34
# 278829  278830   28
# 278830  278831   34
# 278831  278832   62
# 278832  278833   25
# 278833  278834   34
# 278834  278835   18
# 278835  278836   47
# 278836  278837   34
# 278837  278838   15
# 278838  278839   34
# 278839  278840   45
# 278840  278841   34
# 278841  278842   34
# 278842  278843   28
# 278843  278844   28
# 278844  278845   34
# 278845  278846   23
# 278846  278847   34
# 278847  278848   34
# 278848  278849   23
# 278849  278850   34
# 278850  278851   33
# 278851  278852   32
# 278852  278853   17
# 278853  278854   34
# 278854  278855   50
# 278855  278856   34
# 278856  278857   34
# 278857  278858   34
#
# [278858 rows x 2 columns]

# %%
#Plot for Age distribution of users
import matplotlib.pyplot as plt
dfusers.Age.plot.hist(bins=10)
plt.title("Distribution of Users' Ages")
plt.ylabel('Number of Users')
plt.xlabel('Age');

# %% [markdown]
# We can see from the plot that the most active users who rated are between the ages of 20-30s.

# %% [markdown]
# ## Ratings Dataset

# %% [markdown]
# ###### Let's inspect the ratings dataset by drawing a histogram

# %%
#viewing columns in Ratings dataframe
dfratings.columns
# Out:
# Index(['UserID', 'ISBN', 'Ratings'], dtype='object')

# %%
#checks details for ratings dataframe using info()
dfratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
# UserID     1149780 non-null int64
# ISBN       1149780 non-null object
# Ratings    1149780 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
#viewing count of records in each column
dfratings.count()
# Out:
# UserID     1149780
# ISBN       1149780
# Ratings    1149780
# dtype: int64

# %%
#Checking for any missing values
dfratings.isnull().sum()

# %%
#Viewing description of all columns of Ratings dataframe  
dfratings.describe(include='all')

# %%
#Checking for any duplicates
dfratings.duplicated()

# %%
#view data in the Ratings dataset
dfratings

# %%
#plotting histogram based on the ratings data set
import matplotlib.pyplot as plt
dfratings.Ratings.value_counts(sort=False).plot(kind='bar')
plt.rc("font", size=20)
plt.xlabel('ratings')
plt.ylabel('count')
plt.title('Ratings of Books \n')
plt.show()

# %% [markdown]
# From the plot we can observe that zero ratings are the most, followed by ratings of 8 and 10. While ratings of 1 are very low.

# %%
#Count ratings of books by using group by on ISBN and then displaying the Top 10 results from highest rating to lowest
BookRatingsCount = pd.DataFrame(dfratings.groupby('ISBN')['Ratings'].count())
BookRatingsCount.sort_values('Ratings', ascending=False).head(10)

# %% [markdown]
# We are able to see the book that has the most ratings is ISBN: 0971880107 with 2502 ratings.

# %% [markdown]
# ##### Let's see the details of which are the Top 10 rated Books

# %%
Top10RatedBooks = pd.DataFrame(['0971880107', '0316666343', '0385504209', '0060928336', '0312195516', '044023722X', '0679781587', '0142001740', '067976402X', '0671027360'], index=np.arange(10), columns = ['ISBN'])
Summary_Top10RatedBooks = pd.merge(Top10RatedBooks, dfbooks, on='ISBN')
Summary_Top10RatedBooks.head(10)

# %%
#Finally we merge the Ratings and Books dataset
books_data = pd.merge(dfbooks, dfratings, on='ISBN')
books_data
# Out:
#                ISBN                                              Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# 5        0002005018                                       Clara Callan
# 6        0002005018                                       Clara Callan
# 7        0002005018                                       Clara Callan
# 8        0002005018                                       Clara Callan
# 9        0002005018                                       Clara Callan
# 10       0002005018                                       Clara Callan
# 11       0002005018                                       Clara Callan
# 12       0002005018                                       Clara Callan
# 13       0002005018                                       Clara Callan
# 14       0002005018                                       Clara Callan
# 15       0060973129                               Decision in Normandy
# 16       0060973129                               Decision in Normandy
# 17       0060973129                               Decision in Normandy
# 18       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 19       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 20       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 21       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 22       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 23       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 24       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 25       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 26       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 27       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 28       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 29       0393045218                             The Mummies of Urumchi
# ...             ...                                                ...
# 1031106  0878576568              Biopotency: A Guide in Sexual Success
# 1031107  0747204020                  Illustrated Encyclopedia of Cacti
# 1031108  0070542023                       Basic Scientific Subroutines
# 1031109  0070704309                  Electronic filter design handbook
# 1031110  0471915645  Introductory Digital Signal Processing with Co...
# 1031111  8420614556  Lewis Carroll: A Traves Del Espejo Y Lo Que Al...
# 1031112  3320016822  Urteil ohne Prozess: Margot Honecker gegen Oss...
# 1031113  3423200944  Hokuspokus, liebe mich. Und fÃ?Â¼nfzig andere ...
# 1031114  3453065123  Ich war Hitlerjunge Salomon. ( erlebt und erfa...
# 1031115  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 1031116  3548740146       Wicca. Eine EinfÃ?Â¼hrung in weiÃ?Â?e Magie.
# 1031117  381440176X  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...
# 1031118  3893312307  Die Vereinten Nationen: Zwischen Anspruch und ...
# 1031119  0316640786  Christie's Collectables: Blue and White China ...
# 1031120  3257217323                       Schmatz. Oder Die Sackgasse.
# 1031121  3596156904                                              Amok.
# 1031122  0684860112        Driving to Detroit: Memoirs of a Fast Woman
# 1031123  0395264707                                         Dreamsnake
# 1031124  0231128444                      Slow Food(The Case For Taste)
# 1031125  0520242335  Strong Democracy : Participatory Politics for ...
# 1031126  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 1031127  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 1031128  1845170423                                  Cocktail Classics
# 1031129  014002803X                                  Anti Death League
# 1031130  0449906736      Flashpoints: Promise and Peril in a New World
# 1031131  0440400988                         There's a Bat in Bunk Five
# 1031132  0525447644                            From One to One Hundred
# 1031133  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031134  0192126040                        Republic (World's Classics)
# 1031135  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                           Author  YearOfPublication  \
# 0             Mark P. O. Morford               2002
# 1           Richard Bruce Wright               2001
# 2           Richard Bruce Wright               2001
# 3           Richard Bruce Wright               2001
# 4           Richard Bruce Wright               2001
# 5           Richard Bruce Wright               2001
# 6           Richard Bruce Wright               2001
# 7           Richard Bruce Wright               2001
# 8           Richard Bruce Wright               2001
# 9           Richard Bruce Wright               2001
# 10          Richard Bruce Wright               2001
# 11          Richard Bruce Wright               2001
# 12          Richard Bruce Wright               2001
# 13          Richard Bruce Wright               2001
# 14          Richard Bruce Wright               2001
# 15                  Carlo D'Este               1991
# 16                  Carlo D'Este               1991
# 17                  Carlo D'Este               1991
# 18              Gina Bari Kolata               1999
# 19              Gina Bari Kolata               1999
# 20              Gina Bari Kolata               1999
# 21              Gina Bari Kolata               1999
# 22              Gina Bari Kolata               1999
# 23              Gina Bari Kolata               1999
# 24              Gina Bari Kolata               1999
# 25              Gina Bari Kolata               1999
# 26              Gina Bari Kolata               1999
# 27              Gina Bari Kolata               1999
# 28              Gina Bari Kolata               1999
# 29               E. J. W. Barber               1999
# ...                          ...                ...
# 1031106            Ricard Berger               1987
# 1031107            Glass Charles               1991
# 1031108         Fred Ruckdeschel               1981
# 1031109  Arthur Bernard Williams               1981
# 1031110             Paul A. Lynn               1989
# 1031111            Lewis Carroll               1986
# 1031112        JÃ¶rn Kalkbrenner               1990
# 1031113             Helen Glisic               1997
# 1031114              Sally Perel               1993
# 1031115       Hans-Ulrich Wehler               1994
# 1031116         Scott Cunningham               2001
# 1031117              Stefan Wolf               1989
# 1031118           GÃ¼nther Unser               1995
# 1031119             Paul Tippett               1997
# 1031120   Hans Werner Kettenbach               2003
# 1031121         Emmanuel Carrere               2003
# 1031122          Lesley Hazleton               1999
# 1031123        Vonda N. McIntyre               1978
# 1031124            Carlo Petrini               2003
# 1031125       Benjamin R. Barber               2004
# 1031126           Allan Armitage               2002
# 1031127    Allen M., Ph.D. Young               2001
# 1031128              David Biggs               2004
# 1031129            Kingsley Amis               1975
# 1031130             Robin Wright               1993
# 1031131           Paula Danziger               1988
# 1031132               Teri Sloat               1991
# 1031133         Christine Wicker               2004
# 1031134                    Plato               1996
# 1031135      Christopher  Biffle               2000
#
#                                                 Publisher  UserID  Ratings
# 0                                 Oxford University Press       2        0
# 1                                   HarperFlamingo Canada       8        5
# 2                                   HarperFlamingo Canada   11400        0
# 3                                   HarperFlamingo Canada   11676        8
# 4                                   HarperFlamingo Canada   41385        0
# 5                                   HarperFlamingo Canada   67544        8
# 6                                   HarperFlamingo Canada   85526        0
# 7                                   HarperFlamingo Canada   96054        0
# 8                                   HarperFlamingo Canada  116866        9
# 9                                   HarperFlamingo Canada  123629        9
# 10                                  HarperFlamingo Canada  177458        0
# 11                                  HarperFlamingo Canada  200273        8
# 12                                  HarperFlamingo Canada  210926        9
# 13                                  HarperFlamingo Canada  219008        7
# 14                                  HarperFlamingo Canada  263325        6
# 15                                        HarperPerennial       8        0
# 16                                        HarperPerennial    2954        8
# 17                                        HarperPerennial  152827        7
# 18                                   Farrar Straus Giroux       8        0
# 19                                   Farrar Straus Giroux   35704        6
# 20                                   Farrar Straus Giroux   83160        0
# 21                                   Farrar Straus Giroux  110912       10
# 22                                   Farrar Straus Giroux  137688        0
# 23                                   Farrar Straus Giroux  157969        8
# 24                                   Farrar Straus Giroux  169187        0
# 25                                   Farrar Straus Giroux  192665        8
# 26                                   Farrar Straus Giroux  197659        9
# 27                                   Farrar Straus Giroux  208059        6
# 28                                   Farrar Straus Giroux  209163        0
# 29                             W. W. Norton &amp; Company       8        0
# ...                                                   ...     ...      ...
# 1031106                                     St Martins Pr  273190        0
# 1031107                                          Headline  273718       10
# 1031108                                        Byte Books  273971        0
# 1031109                                       McGraw-Hill  273971        0
# 1031110                             John Wiley &amp; Sons  273971        0
# 1031111                            Lectorum Pubns (Adult)  274144        7
# 1031112                                             Dietz  274220        7
# 1031113                                               Dtv  274220       10
# 1031114                                             Heyne  274220        9
# 1031115                        Vandenhoeck &amp; Ruprecht  274220        8
# 1031116                              Ullstein TB-Vlg., B.  274220        6
# 1031117                                           Pelikan  274220        8
# 1031118            Bundeszentrale fÃ¼r Politische Bildung  274220        0
# 1031119                              Time Warner Books UK  274308        0
# 1031120                                   Diogenes Verlag  274719        0
# 1031121                          Fischer (Tb.), Frankfurt  274719        0
# 1031122             Simon &amp; Schuster (Trade Division)  275306        0
# 1031123                                  Houghton Mifflin  275318       10
# 1031124                         Columbia University Press  275970        0
# 1031125                    University of California Press  275970        0
# 1031126                     Running Press Book Publishers  275970        0
# 1031127             Golden Guides from St. Martin's Press  275970        0
# 1031128                                         Connaught  275970        7
# 1031129                                      Viking Press  276077        0
# 1031130                                  Ballantine Books  276313        5
# 1031131                   Random House Childrens Pub (Mm)  276463        7
# 1031132                                      Dutton Books  276579        4
# 1031133                                HarperSanFrancisco  276680        0
# 1031134                           Oxford University Press  276680        0
# 1031135  McGraw-Hill Humanities/Social Sciences/Languages  276680        0
#
# [1031136 rows x 7 columns]

# %%
#Get description of books_data
books_data.describe(include='all')
# Out:
#               ISBN        Title        Author  YearOfPublication  \
# count      1031136      1031136       1031135       1.031136e+06
# unique      270151       241071        101587                NaN
# top     0971880107  Wild Animus  Stephen King                NaN
# freq          2502         2502         10053                NaN
# mean           NaN          NaN           NaN       1.995282e+03
# std            NaN          NaN           NaN       7.308325e+00
# min            NaN          NaN           NaN       1.376000e+03
# 25%            NaN          NaN           NaN       1.992000e+03
# 50%            NaN          NaN           NaN       1.997000e+03
# 75%            NaN          NaN           NaN       2.001000e+03
# max            NaN          NaN           NaN       2.004000e+03
#
#                Publisher        UserID       Ratings
# count            1031134  1.031136e+06  1.031136e+06
# unique             16726           NaN           NaN
# top     Ballantine Books           NaN           NaN
# freq               34724           NaN           NaN
# mean                 NaN  1.405945e+05  2.839051e+00
# std                  NaN  8.052466e+04  3.854157e+00
# min                  NaN  2.000000e+00  0.000000e+00
# 25%                  NaN  7.041500e+04  0.000000e+00
# 50%                  NaN  1.412100e+05  0.000000e+00
# 75%                  NaN  2.114260e+05  7.000000e+00
# max                  NaN  2.788540e+05  1.000000e+01

# %%
#save final processed data to csv
books_data.to_csv(r'../data/processed/Merged.csv', index = None, header=True)

# %%
#save final processed data to csv
dfratings.to_csv(r'../data/processed/RatingsFinal.csv', index = None, header=True)

# %%
#save final processed data to csv
dfusers.to_csv(r'../data/processed/UsersFinal.csv', index = None, header=True)

# %%
#save final processed data to csv
dfbooks.to_csv(r'../data/processed/BooksFinal.csv', index = None, header=True)

# %%
dfbooks.ISBN.isna().sum()
# Out:
# 0

# %% [markdown]
# # END OF NOTEBOOK
